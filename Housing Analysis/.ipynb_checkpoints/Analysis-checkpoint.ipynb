# %%
# previa para hacer ETL de procesado

# %%
import boto3
import psycopg2
import pandas as pd

# %%
def execute_query(q):
    connection = psycopg2.connect(database="Housing",
                                              host="localhost",
                                              user="postgres",
                                              password=db_pass,
                                              port=5432)

    try:
        df = pd.read_sql(q, connection)
        return df
    except Exception as e:
        raise e
    finally:
        connection.close()

# %%
ssm = boto3.client("ssm", region_name="eu-west-1")
db_pass = ssm.get_parameter(Name="POSTGRESQL_PASS", WithDecryption=True)
db_pass = db_pass["Parameter"]["Value"]


df = execute_query('SELECT * FROM houses_scrapper LIMIT 10')
# Out:
# C:\Users\jcf\AppData\Local\Temp\ipykernel_20468\2515250413.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('SELECT * FROM houses_scrapper LIMIT 10', connection)
#           id                                                url  \
# 0  184556206  https://www.fotocasa.es/es/alquiler/vivienda/m...
# 1  184556204  https://www.fotocasa.es/es/alquiler/vivienda/c...
# 2  184556200  https://www.fotocasa.es/es/alquiler/vivienda/v...
# 3  184556196  https://www.fotocasa.es/es/alquiler/vivienda/s...
# 4  184556134  https://www.fotocasa.es/es/alquiler/vivienda/m...
# 5  184556128  https://www.fotocasa.es/es/alquiler/vivienda/s...
# 6  184556076  https://www.fotocasa.es/es/alquiler/vivienda/t...
# 7  184556074  https://www.fotocasa.es/es/alquiler/vivienda/g...
# 8  184556065  https://www.fotocasa.es/es/alquiler/vivienda/b...
# 9  184556044  https://www.fotocasa.es/es/alquiler/vivienda/b...
#
#                          timestamp  price  rooms  bathrooms  surface  \
# 0 2024-10-13 20:11:49.450985+00:00  650.0      2          1       70
# 1 2024-10-13 20:11:52.308060+00:00  385.0      2          1       57
# 2 2024-10-13 20:11:56.175536+00:00  385.0      2          1       60
# 3 2024-10-13 20:12:01.953136+00:00  385.0      2          1       57
# 4 2024-10-13 20:12:07.152511+00:00  385.0      2          1       60
# 5 2024-10-13 20:12:11.360486+00:00  385.0      2          1       60
# 6 2024-10-13 20:12:14.506817+00:00  385.0      2          1       57
# 7 2024-10-13 20:12:16.655994+00:00  385.0      2          1       57
# 8 2024-10-13 20:12:19.591571+00:00  385.0      2          1       57
# 9 2024-10-13 20:12:22.075664+00:00  385.0      2          1       57
#
#                        street_name                   city  type orientation  \
# 0  Passatge de Montserrat Domènech              Martorell  Piso        None
# 1           Carrer de la Llibertat          Castelldefels  Piso        None
# 2                Passeig del Carme   Vilanova i la Geltrú  Piso        None
# 3  Carrer de Francesc Pi I Margall  Sant Boi de Llobregat  Piso        None
# 4                  Carrer del Bruc                Manresa  Piso        None
# 5          Carrer de Narcís Giralt               Sabadell  Piso        None
# 6              Carrer del Col·legi               Terrassa  Piso        None
# 7                 Carrer Guayaquil             Granollers  Piso        None
# 8           Carrer del Dos de Maig               Badalona  Piso        None
# 9        Carrer de Roger de Llúria      Barcelona Capital  Piso        None
#
#     age  parking      floor  elevator  furniture  active     state  energy  \
# 0  None  Privado       None      True       True    True  Muy bien     999
# 1  None  Privado  1ª planta      True      False    True      None  Exento
# 2  None     None       None      True      False    True      None  Exento
# 3  None  Privado  1ª planta      True      False    True      None  Exento
# 4  None     None       None      True      False    True      None  Exento
# 5  None     None       None      True      False    True      None  Exento
# 6  None  Privado  1ª planta      True      False    True      None  Exento
# 7  None  Privado  1ª planta      True      False    True      None  Exento
# 8  None  Privado  1ª planta      True      False    True      None  Exento
# 9  None  Privado  1ª planta      True      False    True      None  Exento
#
#   emissions
# 0       999
# 1    Exento
# 2    Exento
# 3    Exento
# 4    Exento
# 5    Exento
# 6    Exento
# 7    Exento
# 8    Exento
# 9    Exento

# %%
connection.close()
